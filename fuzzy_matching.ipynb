# %% [markdown]
# To run the following script, install the following:
#
# - pip install python-Levenshtein
# - pip install fuzzywuzzy
#
# Levenshtein may require a Microsoft C++ build package through Visual Studio. Follow prompts as required

# %%
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
# Standardized shipping methods based primarily upon what is selectable through the FedEx API here:
# https://www.fedex.com/ratefinder/home. 'Home Delivery' and 'Smartpost' are not selectable
# through the API. This is because these services are available to businesses only.
fedex_methods = ['Same Day', 'First Overnight', 'Priority Overnight', 'First Overnight',
                 'Priority Overnight', 'Standard Overnight', '2Day AM', '2Day', 'Express Saver',
                 'Ground','Home Delivery','Smartpost']

# Standardized shipping methods based primarily on what is selectable through the API here:
# https://wwwapps.ups.com/ctc/request?loc=en_US. 'Surepost' and 'Standard' are not selectable
# through the API. Standard is Ground to the 48 continguous states, whereas Ground includes
# Alaska and Hawaii.
ups_methods = ['Next Day Air Early', 'Next Day Air', 'Next Day Air Saver',
               '2nd Day Air A.M.', '2nd Day Air', '3 Day Select', 'Ground', 'Surepost', 'Standard']

# %%
# Reads in and labels the data.
data = pd.read_pickle('C:/Users/bjtur/Documents/Capstone/test_merged.pickle')
data.columns = ['year_week', 'business_sid', 'industry', 'sub_industry', 'shipper',
       'service_type', 'package_count', 'weight', 'shipment_date',
       'delivery_date', 'delivery_time', 'freight_charges',
       'freight_discount_amount', 'misc_charges', 'misc_discount_amount',
       'net_charge_amount', 'zone', 'sender_city', 'sender_zip',
       'recipient_city', 'recipient_zip']

# %%
data_sample = data.sample(frac=0.1, replace=False)

# %%
data_sample = data_sample[data_sample.zone.apply(lambda x: x.isnumeric())]
data_sample = data_sample.astype({'freight_charges':'float64',
                                  'freight_discount_amount':'float64',
                                  'misc_charges':'float64',
                                  'misc_discount_amount':'float64',
                                  'net_charge_amount':'float64',
                                  'zone':'int64'})
data_sample.zone %= 10

# %%
# Applies the 'fuzz.partial_ratio' fuzzy macthing algorithm to each record based upon the record's service_type.
# The partial_ratio function is designed to return the shipping method with the highest score as a two pair tuple
# i.e., (standardized_shipping, score)

data_fuzzy_match = []
for row in data_sample[['shipper','service_type']].itertuples():
    if row.shipper == 'fedex':
        data_fuzzy_match.append(process.extractOne(
            row.service_type,
            fedex_methods,
            scorer = fuzz.partial_ratio))
    else:
        data_fuzzy_match.append(process.extractOne(
            row.service_type,
            ups_methods,
            scorer = fuzz.partial_ratio))

# %%
print(len(data_sample))
data_sample.insert(6, 'std_service_type', [method for method, score in data_fuzzy_match])
data_sample = data_sample.assign(std_service_type_score = [score for method, score in data_fuzzy_match])
data_sample = data_sample[data_sample.std_service_type_score >= 70]
data_sample = data_sample.drop('std_service_type_score', axis=1)
print(len(data_sample))
# Out:
# 372292
# 365777

# %%
a = 1
a.astype(str)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-3654b4956413> in <module>
#       1 a = 1
# ----> 2 a.astype(str)
#
# AttributeError: 'int' object has no attribute 'astype'

# %%
data = pd.read_pickle('test_merged.pickle')

# %%
data.dtypes
# Out:
# year_week                            int64
# business_sid                        object
# industry                            object
# sub_industry                        object
# shipper                             object
# service_type                        object
# std_service_type                    object
# package_count                        int64
# weight                             float64
# shipment_date               datetime64[ns]
# delivery_date               datetime64[ns]
# delivery_time              timedelta64[ns]
# freight_charges                    float64
# freight_discount_amount            float64
# misc_charges                       float64
# misc_discount_amount               float64
# net_charge_amount                  float64
# zone                                object
# sender_city                         object
# sender_state                        object
# sender_zip                          object
# recipient_city                      object
# recipient_state                     object
# recipient_zip                       object
# dtype: object

# %%
data[(~data.recipient_state.isin(state_abbs)) & (data.recipient_state != '')]
data[(~data.sender_state.isin(state_abbs)) & (data.sender_state != '')]
# Out:
#          year_week business_sid                industry  \
# 580322      201828   0C88F8BDE6                    None
# 586425      201836   D86C057DE2                  RETAIL
# 586406      201836   D86C057DE2                  RETAIL
# 1611824     201838   73C6D0DBE2                  RETAIL
# 586423      201836   D86C057DE2                  RETAIL
# 586418      201836   D86C057DE2                  RETAIL
# 683312      201840   0309614A6E                   OTHER
# 1001770     201849   66FD113B5A                   OTHER
# 1308835     201849   4A69F06503                    None
# 1380        201901   GVA9UDFMG6          TRANSPORTATION
# 1010009     201903   BFE4AB6D4F                  RETAIL
# 926876      201907   469D46A3EA  WHOLESALE/DISTRIBUTORS
# 651282      201910   469D46A3EA  WHOLESALE/DISTRIBUTORS
# 1023676     201911   469D46A3EA  WHOLESALE/DISTRIBUTORS
# 1541119     201912   469D46A3EA  WHOLESALE/DISTRIBUTORS
# 651278      201910   469D46A3EA  WHOLESALE/DISTRIBUTORS
# 1023679     201911   469D46A3EA  WHOLESALE/DISTRIBUTORS
# 66324       201909   469D46A3EA  WHOLESALE/DISTRIBUTORS
# 1454463     201916   469D46A3EA  WHOLESALE/DISTRIBUTORS
# 448209      201914   469D46A3EA  WHOLESALE/DISTRIBUTORS
# 908705      201915   469D46A3EA  WHOLESALE/DISTRIBUTORS
# 908692      201915   469D46A3EA  WHOLESALE/DISTRIBUTORS
# 448210      201914   469D46A3EA  WHOLESALE/DISTRIBUTORS
# 448213      201914   469D46A3EA  WHOLESALE/DISTRIBUTORS
# 908695      201915   469D46A3EA  WHOLESALE/DISTRIBUTORS
# 990720      201915   INH8DLJ8T6                  RETAIL
# 26649       201913   70D24491E3                SERVICES
# 18530       201913   469D46A3EA  WHOLESALE/DISTRIBUTORS
# 18542       201913   469D46A3EA  WHOLESALE/DISTRIBUTORS
# 448211      201914   469D46A3EA  WHOLESALE/DISTRIBUTORS
# 9891        201917   469D46A3EA  WHOLESALE/DISTRIBUTORS
# 9893        201917   469D46A3EA  WHOLESALE/DISTRIBUTORS
# 9886        201917   469D46A3EA  WHOLESALE/DISTRIBUTORS
# 574878      201918   469D46A3EA  WHOLESALE/DISTRIBUTORS
# 1081051     201919   469D46A3EA  WHOLESALE/DISTRIBUTORS
# 1606284     201920   469D46A3EA  WHOLESALE/DISTRIBUTORS
# 169934      201921   469D46A3EA  WHOLESALE/DISTRIBUTORS
# 169945      201921   469D46A3EA  WHOLESALE/DISTRIBUTORS
# 169941      201921   469D46A3EA  WHOLESALE/DISTRIBUTORS
# 169946      201921   469D46A3EA  WHOLESALE/DISTRIBUTORS
#
#                                    sub_industry shipper  \
# 580322                                     None   fedex
# 586425                                ECOMMERCE   fedex
# 586406                                ECOMMERCE   fedex
# 1611824                             MISC RETAIL   fedex
# 586423                                ECOMMERCE   fedex
# 586418                                ECOMMERCE   fedex
# 683312                                    OTHER   fedex
# 1001770                                   OTHER   fedex
# 1308835                                    None     ups
# 1380     MOTOR FREIGHT TRANSPORTATION/WAREHOUSE   fedex
# 1010009                             MISC RETAIL   fedex
# 926876            WHOLESALE TRADE-DURABLE GOODS   fedex
# 651282            WHOLESALE TRADE-DURABLE GOODS   fedex
# 1023676           WHOLESALE TRADE-DURABLE GOODS   fedex
# 1541119           WHOLESALE TRADE-DURABLE GOODS   fedex
# 651278            WHOLESALE TRADE-DURABLE GOODS   fedex
# 1023679           WHOLESALE TRADE-DURABLE GOODS   fedex
# 66324             WHOLESALE TRADE-DURABLE GOODS   fedex
# 1454463           WHOLESALE TRADE-DURABLE GOODS   fedex
# 448209            WHOLESALE TRADE-DURABLE GOODS   fedex
# 908705            WHOLESALE TRADE-DURABLE GOODS   fedex
# 908692            WHOLESALE TRADE-DURABLE GOODS   fedex
# 448210            WHOLESALE TRADE-DURABLE GOODS   fedex
# 448213            WHOLESALE TRADE-DURABLE GOODS   fedex
# 908695            WHOLESALE TRADE-DURABLE GOODS   fedex
# 990720                                ECOMMERCE   fedex
# 26649                      EDUCATIONAL SERVICES   fedex
# 18530             WHOLESALE TRADE-DURABLE GOODS   fedex
# 18542             WHOLESALE TRADE-DURABLE GOODS   fedex
# 448211            WHOLESALE TRADE-DURABLE GOODS   fedex
# 9891              WHOLESALE TRADE-DURABLE GOODS   fedex
# 9893              WHOLESALE TRADE-DURABLE GOODS   fedex
# 9886              WHOLESALE TRADE-DURABLE GOODS   fedex
# 574878            WHOLESALE TRADE-DURABLE GOODS   fedex
# 1081051           WHOLESALE TRADE-DURABLE GOODS   fedex
# 1606284           WHOLESALE TRADE-DURABLE GOODS   fedex
# 169934            WHOLESALE TRADE-DURABLE GOODS   fedex
# 169945            WHOLESALE TRADE-DURABLE GOODS   fedex
# 169941            WHOLESALE TRADE-DURABLE GOODS   fedex
# 169946            WHOLESALE TRADE-DURABLE GOODS   fedex
#
#                                 service_type std_service_type  package_count  \
# 580322                                ground           Ground              1
# 586425                                ground           Ground              1
# 586406                                ground           Ground              1
# 1611824                               ground           Ground              1
# 586423                                ground           Ground              1
# 586418                                ground           Ground              1
# 683312                         home delivery    Home Delivery              1
# 1001770                               ground           Ground              1
# 1308835  ups surepost - less than 1 lb\t2\t3         Surepost              1
# 1380                                  ground           Ground              1
# 1010009                               ground           Ground              1
# 926876                   FedEx Home Delivery    Home Delivery              1
# 651282                          FedEx Ground           Ground              1
# 1023676                  FedEx Home Delivery    Home Delivery              1
# 1541119                  FedEx Home Delivery    Home Delivery              1
# 651278                   FedEx Home Delivery    Home Delivery              1
# 1023679                  FedEx Home Delivery    Home Delivery              1
# 66324                    FedEx Home Delivery    Home Delivery              1
# 1454463                  FedEx Home Delivery    Home Delivery              1
# 448209                         home delivery    Home Delivery              1
# 908705                          FedEx Ground           Ground              1
# 908692                   FedEx Home Delivery    Home Delivery              1
# 448210                         home delivery    Home Delivery              1
# 448213                         home delivery    Home Delivery              1
# 908695                   FedEx Home Delivery    Home Delivery              1
# 990720                          FedEx Ground           Ground              1
# 26649                           FedEx Ground           Ground              1
# 18530                    FedEx Home Delivery    Home Delivery              1
# 18542                    FedEx Home Delivery    Home Delivery              1
# 448211                         home delivery    Home Delivery              1
# 9891                            FedEx Ground           Ground              1
# 9893                     FedEx Home Delivery    Home Delivery              1
# 9886                     FedEx Home Delivery    Home Delivery              1
# 574878                   FedEx Home Delivery    Home Delivery              1
# 1081051                        home delivery    Home Delivery              1
# 1606284                         FedEx Ground           Ground              1
# 169934                   FedEx Home Delivery    Home Delivery              1
# 169945                   FedEx Home Delivery    Home Delivery              1
# 169941                   FedEx Home Delivery    Home Delivery              1
# 169946                          FedEx Ground           Ground              1
#
#          weight shipment_date  ... misc_charges misc_discount_amount  \
# 580322     35.6    2018-06-20  ...         0.00                 0.00
# 586425     36.0    2018-08-16  ...         1.72                 0.00
# 586406     36.0    2018-08-16  ...         1.72                 0.00
# 1611824    20.1    2018-08-29  ...         0.00                 0.00
# 586423     40.0    2018-08-16  ...         1.88                 0.00
# 586418     36.0    2018-08-16  ...         1.72                 0.00
# 683312     53.0    2018-09-13  ...        28.44                 0.00
# 1001770    42.0    2018-11-19  ...        10.29                 0.00
# 1308835    10.9    2018-11-26  ...         3.14                 0.26
# 1380       15.0    2018-12-14  ...         2.25                 0.00
# 1010009    18.0    2019-01-02  ...         0.90                 0.00
# 926876     20.0    2019-01-25  ...         4.82                 0.00
# 651282     51.0    2019-02-18  ...        14.77                 0.00
# 1023676     6.0    2019-02-21  ...         4.02                 0.00
# 1541119    34.0    2019-03-01  ...        18.15                 0.00
# 651278     54.0    2019-02-18  ...         5.48                 0.00
# 1023679    54.0    2019-02-25  ...         5.48                 0.00
# 66324      54.0    2019-02-12  ...         4.43                 0.00
# 1454463     6.0    2019-04-02  ...         9.11                 0.00
# 448209     20.0    2019-03-15  ...         9.48                 0.00
# 908705     53.0    2019-03-27  ...         6.37                 0.00
# 908692      3.0    2019-03-15  ...         3.97                 0.00
# 448210     26.0    2019-03-21  ...        23.15                 0.00
# 448213     16.0    2019-03-21  ...         9.10                 0.00
# 908695     54.0    2019-03-21  ...        14.76                 0.00
# 990720      6.0    2019-03-26  ...         0.63                 0.00
# 26649       6.0    2019-03-08  ...        14.52                 0.00
# 18530      51.0    2019-03-07  ...        19.86                 0.00
# 18542       6.0    2019-03-13  ...         9.01                 0.00
# 448211     34.0    2019-03-21  ...        23.58                 0.00
# 9891       37.0    2019-04-03  ...         9.54                 0.00
# 9893       34.0    2019-04-08  ...        24.67                 0.00
# 9886       31.0    2019-04-02  ...        24.47                 0.00
# 574878     34.0    2019-04-08  ...        23.02                 0.00
# 1081051    36.0    2019-04-23  ...        23.44                 0.00
# 1606284    18.0    2019-04-29  ...         5.95                 0.00
# 169934     35.0    2019-05-01  ...        24.04                 0.00
# 169945     17.0    2019-05-07  ...        14.21                 0.00
# 169941      6.0    2019-05-03  ...         9.04                 0.00
# 169946      6.0    2019-05-07  ...        10.74                 0.00
#
#          net_charge_amount  zone      sender_city  sender_state  sender_zip  \
# 580322               29.97     6        STRATFORD            ON       N4Z0A
# 586425               29.24     6       CORNWALLIS            NS       B0S1H
# 586406               29.24     6       CORNWALLIS            NS       B0S1H
# 1611824              17.36     2          CALGARY            AB       T2J5Y
# 586423               31.96     6       CORNWALLIS            NS       B0S1H
# 586418               29.24     6       CORNWALLIS            NS       B0S1H
# 683312               63.94     6       PARKSVILLE            BC       V9P2W
# 1001770              24.88     4         OAKVILLE            ON       L6J7Z
# 1308835               8.23     4           EASTON            US       61265
# 1380                 24.83     8          MARKHAM            ON       L6G1A
# 1010009              14.26     3           DORVAL            PQ       H9P1J
# 926876               23.37     8          TORONTO            ON       M6B4K
# 651282               24.99     2          TORONTO            ON       M6B4K
# 1023676              13.87     8          TORONTO            ON       M6B4K
# 1541119              31.17     4          TORONTO            ON       M6B4K
# 651278               31.30     6          TORONTO            ON       M6B4K
# 1023679              31.30     6          TORONTO            ON       M6B4K
# 66324                18.72     3          TORONTO            ON       M6B4K
# 1454463              18.02     6          TORONTO            ON       M6B4K
# 448209               23.04     6          TORONTO            ON       M6B4K
# 908705               19.17     3          TORONTO            ON       M6B4K
# 908692               13.02     8          TORONTO            ON       M6B4K
# 448210               34.13     4          TORONTO            ON       M6B4K
# 448213               17.88     4          TORONTO            ON       M6B4K
# 908695               40.58     6          TORONTO            ON       M6B4K
# 990720                9.63     2  NEW WESTMINSTER            BC       V3M5K
# 26649                27.15     5    SAINT LAURENT            PQ       H4T1A
# 18530                50.70     7          TORONTO            ON       M6B4K
# 18542                17.60     5          TORONTO            ON       M6B4K
# 448211               39.00     5          TORONTO            ON       M6B4K
# 9891                 24.51     5          TORONTO            ON       M6B4K
# 9893                 51.36     8          TORONTO            ON       M6B4K
# 9886                 49.00     8          TORONTO            ON       M6B4K
# 574878               32.62     2          TORONTO            ON       M6B4K
# 1081051              37.01     4          TORONTO            ON       M6B4K
# 1606284              14.16     4          TORONTO            ON       M6B4K
# 169934               43.56     6          TORONTO            ON       M6B4K
# 169945               23.19     4          TORONTO            ON       M6B4K
# 169941               16.89     3          TORONTO            ON       M6B4K
# 169946               18.59     3          TORONTO            ON       M6B4K
#
#            recipient_city recipient_state recipient_zip
# 580322       FORT COLLINS              CO         80524
# 586425        SPRINGFIELD              MO         65802
# 586406        SPRINGFIELD              MO         65802
# 1611824            MEDLEY              FL         33178
# 586423        SPRINGFIELD              MO         65802
# 586418        SPRINGFIELD              MO         65802
# 683312             SEDONA              AZ         86336
# 1001770           CONCORD              NC         28027
# 1308835          STERLING              OH         44276
# 1380              BOTHELL              WA         98021
# 1010009            EMMAUS              PA         18049
# 926876           DANVILLE              CA         94506
# 651282       ORCHARD PARK              NY         14127
# 1023676          MERIDIAN              ID         83646
# 1541119        CINCINNATI              OH         45255
# 651278          LAFAYETTE              CO         80026
# 1023679           HIALEAH              FL         33015
# 66324          LIVINGSTON              NJ         07039
# 1454463  COLORADO SPRINGS              CO         80924
# 448209             AURORA              KS         67417
# 908705            FAIRFAX              VA         22030
# 908692             CORONA              CA         92881
# 448210            PORTAGE              MI         49002
# 448213      SOUTH HOLLAND              IL         60473
# 908695          THIBODAUX              LA         70301
# 990720            SEATTLE              WA         98119
# 26649              FOWLER              IN         47944
# 18530             MISSION              TX         78572
# 18542         HOWARD LAKE              MN         55349
# 448211         MANCHESTER              MO         63021
# 9891              REDDICK              FL         32686
# 9893        BEVERLY HILLS              CA         90210
# 9886               LOMPOC              CA         93436
# 574878      BEVERLY HILLS              CA         90210
# 1081051         CHARLOTTE              NC         28269
# 1606284        WILMINGTON              NC         28411
# 169934              TAMPA              FL         33607
# 169945        SUGAR GROVE              IL         60554
# 169941       HARRISONBURG              VA         22801
# 169946              BRONX              NY         10463
#
# [40 rows x 24 columns]

# %% [raw]
# data[data.misc_discount_amount > 0].iloc[:,10:].head()

# %%
# Standardized state names and codes of the 48 contiguous states based upon USPS standards found here:
# https://www.ups.com/worldshiphelp/WS14/ENU/AppHelp/Codes/State_Province_Codes.htm
state_names_to_codes = {'Alabama':'AL', 'Arizona':'AZ', 'Arkansas':'AR', 'Armed Forces America':'AA',
 'Armed Forces Europe':'AE', 'Armed Forces Pacific':'AP', 'California':'CA', 'Colorado':'CO',
 'Connecticut':'CT', 'Delaware':'DE', 'District of Columbia':'DC', 'Florida':'FL', 'Georgia':'GA',
 'Hawaii':'HI', 'Idaho':'ID', 'Illinois':'IL', 'Indiana':'IN', 'Iowa':'IA', 'Kansas':'KS', 'Kentucky':'KY',
 'Louisiana':'LA', 'Maine':'ME', 'Maryland':'MD', 'Massachusetts':'MA', 'Michigan':'MI', 'Minnesota':'MN',
 'Mississippi':'MS', 'Missouri':'MO', 'Montana':'MT', 'Nebraska':'NE', 'Nevada':'NV', 'New Hampshire':'NH',
 'New Jersey':'NJ', 'New Mexico':'NM', 'New York':'NY', 'North Carolina':'NC', 'North Dakota':'ND',
 'Ohio':'OH', 'Oklahoma':'OK', 'Oregon':'OR', 'Pennsylvania':'PA', 'Rhode Island':'RI', 'South Carolina':'SC',
 'South Dakota':'SD', 'Tennessee':'TN', 'Texas':'TX', 'Utah':'UT', 'Vermont':'VT', 'Virginia':'VA',
 'Washington':'WA', 'West Virginia':'WV', 'Wisconsin':'WI', 'Wyoming':'WY'}
state_names = list(state_names_to_codes.keys())
state_codes = list(state_names_to_codes.values())

# %%
state_names = list(state_name_to_abb.keys())

# %%
state_names
# Out:
# ['Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'Armed Forces America',
#  'Armed Forces Europe',
#  'Armed Forces Pacific',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'District of Columbia',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming']

# %%
state_abbs = list(state_names_to_abbs.values())

# %%
state_abbs
# Out:
# ['AL',
#  'AK',
#  'AZ',
#  'AR',
#  'AA',
#  'AE',
#  'AP',
#  'CA',
#  'CO',
#  'CT',
#  'DE',
#  'DC',
#  'FL',
#  'GA',
#  'HI',
#  'ID',
#  'IL',
#  'IN',
#  'IA',
#  'KS',
#  'KY',
#  'LA',
#  'ME',
#  'MD',
#  'MA',
#  'MI',
#  'MN',
#  'MS',
#  'MO',
#  'MT',
#  'NE',
#  'NV',
#  'NH',
#  'NJ',
#  'NM',
#  'NY',
#  'NC',
#  'ND',
#  'OH',
#  'OK',
#  'OR',
#  'PA',
#  'RI',
#  'SC',
#  'SD',
#  'TN',
#  'TX',
#  'UT',
#  'VT',
#  'VA',
#  'WA',
#  'WV',
#  'WI',
#  'WY']
